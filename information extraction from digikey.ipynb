# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
from googlesearch import search
from urllib.request import urlopen as ureq
from bs4 import BeautifulSoup
import time
mpn = []
urllis = []
kk1  = []
kk2  = []
kk3  = []
kk4  = []
kk5  = []
kk6  = []
kk7  = []
kk8  = []
kk9  = []
kk10 = []
k=pd.read_excel("C:/Users/****/Downloads/*****.xlsx") 
lister = []
for i in range(k["mpn"].shape[0]):
    lister.append("blank")
for x in range(k["mpn"].shape[0]):
    query = k["mpn"][x]
    query_new = "digikey"+ " " + str(query)
    while True:
        try:
            for j in search(str(query_new), num=5,tld="co.in",stop =5,pause=3):
                
                #if lister[x] == "blank":
                    if j.split(".")[1].split(".")[0]=="digikey":
                        if j.find("product-detail") != -1:
                            if j.find("pdf") == -1:
                                if j.find("pages") == -1:
                                    if j.find(".xml") == -1:
                                        if j.find("DownloadPdf") == -1:
                                            lister[x] = j
                                                       
                                            uclient = ureq(j)
                                            pages_html = uclient.read()
                                            uclient.close()
                                            soup = BeautifulSoup(pages_html)
                                            for script in soup(["script", "style"]):
                                                script.extract()
                                            text = soup.get_text()
                                            lines = (line.strip() for line in text.splitlines())
                                            chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
                                            text = ' '.join(chunk for chunk in chunks if chunk)
                                            text = str(text)
                                            text_new = text
                                            text2 = text
                                            if text.find("Product Attributes") != -1:
                                                '''kk1.append("blank")
                                                kk2.append("blank")
                                                kk3.append("blank")
                                                kk4.append("blank")
                                                kk5.append("blank")
                                                kk6.append("blank")
                                                kk7.append("blank")
                                                kk8.append("blank")
                                                kk9.append("blank")
                                                kk10.append("blank")'''
                                            #else:
                                                if text.find("Documents & Media") != -1:
                                                    text = text.split("Product Index")[1].split("Documents & Media")[0]
                                                else:
                                                    text = text.split("Product Index")[1].split("Product Attributes")[0]
                                                
                                                while True:
                                                    try:
                                                        y = text2.split("Product Index >")[1].split(">")
                                                        kk1.append(("Product Index >" + ">".join(text2.split("Product Index >")[1].split(">")[:len(y)-1])).strip(" "))
                                                        break
                                                    except Exception as e:
                                                        kk1.append("blank")
                                                        break
                                                        
                                                while True:
                                                    try:
                                                        if text.find("Datasheet Digi-Key Part Number") != -1:
                                                            kk2.append((text.split("Datasheet Digi-Key Part Number")[1].split("-ND")[0] + "-ND").strip(" "))
                                                        else:
                                                            kk2.append((text.split("Digi-Key Part Number")[1].split("-ND")[0] + "-ND").strip(" "))
                                                        break
                                                    except Exception as e:
                                                        kk2.append("blank")
                                                        break
                                                        
                                                while True:
                                                    try:
                                                        kk3.append((text.split("Copy Manufacturer")[1]).strip(" "))
                                                        break
                                                    except Exception as e:
                                                        kk3.append("blank")
                                                        break
                                                
                                                
                                                while True:
                                                    try:
                                                        kk4.append((text.split("Manufacturer Part Number")[1].split("Copy Description")[0]).strip(" "))
                                                        break
                                                    except Exception as e:
                                                        kk4.append("blank")
                                                        break
                                                
                                                while True:
                                                    try:
                                                        if text.find("Manufacturer Standard Lead Time") != -1:
                                                            m = (text.split("Description")[1].split("Copy Manufacturer Standard Lead Time")[0].split("Quantity Available")[0]).strip(" ")
                                                            kk5.append(m)
                                                        else:
                                                            m = ((text.split("Description")[1].split("Copy")[0]).strip(" "))
                                                            if m.find("Quantity Available") != -1:
                                                                kk5.append(m.split("Quantity Available")[0].strip(" "))
                                                            else:
                                                                kk5.append(m)
                                                        break
                                                    except Exception as e:
                                                        kk5.append("blank")
                                                        break
                                                while True:
                                                    try:
                                                        if text.find("Detailed Description") != -1:
                                                            if text.find("Copy") != 1:
                                                                y = text.split("Detailed Description")[1].split(" ")
                                                                y.remove("Copy")
                                                                y = " ".join(y)
                                                                y = y.strip(" ")
                                                                kk6.append(y)
                                                            else:
                                                                kk6.append((text.split("Detailed Description")[1].split("Copy Documents & Media")[0]).strip(" "))
                                                        else:
                                                            kk6.append("blank")
                                                        break
                                                    except Exception as e:
                                                        kk6.append("blank")
                                                        break
                                                    
                                                text = text_new.split("Product Attributes")[1].split("Report an Error")[0]
                                                text = text.split("Type Description")[1]
                                                while True:
                                                    try:
                                                        kk7.append(text.split("Categories")[1].split("Manufacturer")[0].strip(" "))
                                                        break
                                                    except Exception as e:
                                                        kk7.append("blank")
                                                        break
                                                while True:
                                                    try:
                                                        if text.find("Packaging") != -1:
                                                            kk8.append(text.split("Series")[1].split("Packaging")[0].strip(" "))
                                                        else:
                                                            kk8.append(text.split("Series")[1].split("Part Status")[0].strip(" "))
                                                        break
                                                    except Exception as e:
                                                        kk8.append("blank")
                                                        break
                                                while True:
                                                    try:
                                                        lis = ["Active","Discontinued at Digi-Key","Not For New Designs","Obsolete","Last Time Buy"]
                                                        for i in range(len(lis)):
                                                            if text.find(lis[i]) != -1:
                                                                kk9.append(lis[i])
                                                        break
                                                    except Exception as e:
                                                        kk9.append("blank")
                                                        break
                                                   
                                                while True:
                                                    try:
                                                        if text.find("Manufacturer") != -1:
                                                            text = text.split("Manufacturer")[1].split("Report an Error")[0]
                                                        if text.find("Type") != -1:
                                                            if text.find("Manufacturer") != -1:
                                                                kk10.append(" ".join(text.split("Manufacturer")[1].split("Type")[1].strip(" ").split(" ")[:3]))
                                                            else:
                                                                kk10.append(" ".join(text.split("Type")[1].strip(" ").split(" ")[:3]))
                                                        else:
                                                            kk10.append("blank")
                                                        break
                                                    except Exception as e:
                                                        kk10.append("blank")
                                                        break
                                                mpn.append(query)
                                                urllis.append(j)
                                        
                                                out = pd.DataFrame(list(zip(mpn,urllis,kk1,kk2,kk3,kk4,kk5,kk6,kk7,kk8,kk9,kk10)), columns =['mpn',"url","hierarchy","Digi-Key Part Number","Manufacturer","Manufacturer Part Number","Description","Detailed Description","Categories","Series","part status","type"]) 
                                                out.to_excel("final_out_new_1.xlsx")
                                                print(x)
                        
                    break                        
            break
        except Exception as e:
            print("no internet")
            print(e)
            time.sleep(300)
            break
